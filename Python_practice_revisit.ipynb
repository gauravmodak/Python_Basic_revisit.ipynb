# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\my pc\\Downloads'

# %%
os.chdir('E:/Gaurav Finance/Revisit')

# %%
os.getcwd()
# Out:
# 'E:\\Gaurav Finance\\Revisit'

# %%
mba=pd.read_csv('E:/Gaurav Finance/Revisit/mba.csv')

# %%
mba
# Out:
#      datasrno  workex  gmat
# 0           1      21   720
# 1           2     107   640
# 2           3      57   740
# 3           4      99   690
# 4           5     208   710
# ..        ...     ...   ...
# 768       769      88   620
# 769       770     132   670
# 770       771      28   610
# 771       772      10   610
# 772       773      52   620
#
# [773 rows x 3 columns]

# %%
pd.set_option("display.max_rows",None)

# %%
mba
# Out:
#      datasrno  workex  gmat
# 0           1      21   720
# 1           2     107   640
# 2           3      57   740
# 3           4      99   690
# 4           5     208   710
# 5           6     136   660
# 6           7      70   660
# 7           8     103   710
# 8           9      79   700
# 9          10      22   730
# 10         11      69   700
# 11         12      41   740
# 12         13      72   650
# 13         14      69   720
# 14         15      20   700
# 15         16      21   760
# 16         17      19   710
# 17         18      86   720
# 18         19     231   690
# 19         20      20   770
# 20         21     175   660
# 21         22      21   710
# 22         23      44   720
# 23         24      23   650
# 24         25      20   710
# 25         26      70   720
# 26         27      46   710
# 27         28      33   650
# 28         29     130   690
# 29         30      57   690
# 30         31      57   750
# 31         32      45   710
# ...

# %%
#to get the info on 619th row in gmat column
mba.loc[619,["gmat"]]
# Out:
# gmat    730
# Name: 619, dtype: int64

# %%
#mean for all columns
mba.mean()
# Out:
# datasrno    387.000000
# workex       57.501940
# gmat        711.164295
# dtype: float64

# %%
#mean,mode,median for particular column
mba['gmat'].mean()
mba['gmat'].median()
mba['gmat'].mode()
# Out:
# 0    710
# dtype: int64

# %%
#display graphs. .available is giving possible options in
#visualisation
plt.style.use(['bmh'])
print (plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.hist(mba['gmat'])
# Out:
# (array([  6.,   9.,  20.,  30.,  54., 143., 282., 143.,  67.,  19.]),
#  array([600., 618., 636., 654., 672., 690., 708., 726., 744., 762., 780.]),
#  <BarContainer object of 10 artists>)

# %%
#another style for visualisation
plt.style.use(['seaborn-darkgrid'])
plt.hist(mba['gmat'])
plt.figure(figsize=(10,5))

# %%
#here 5 is width and 7 is height of the graph
plt.figure(figsize=(8,4))
plt.hist(mba['gmat'])
# Out:
# (array([  6.,   9.,  20.,  30.,  54., 143., 282., 143.,  67.,  19.]),
#  array([600., 618., 636., 654., 672., 690., 708., 726., 744., 762., 780.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(5,6))
plt.hist(mba['gmat'])
# Out:
# (array([  6.,   9.,  20.,  30.,  54., 143., 282., 143.,  67.,  19.]),
#  array([600., 618., 636., 654., 672., 690., 708., 726., 744., 762., 780.]),
#  <BarContainer object of 10 artists>)

# %%
#another style for visualisation
plt.style.use(['dark_background'])
plt.hist(mba['gmat'])
plt.figure(figsize=(10,5))

# %%
#by default it is vertical boxplot
plt.boxplot(mba['gmat'])
plt.style.use(['tableau-colorblind10'])

# %%
#vert = false made this hori graph
plt.boxplot(mba['gmat'],vert= False)
plt.style.use(['tableau-colorblind10'])

# %%
#by default it is vertical boxplot
#1,ys,1 = notch, ys = yellow sqr, 1 = vert plot
plt.boxplot(mba['gmat'],1,'ys',1)
plt.style.use(['tableau-colorblind10'])

# %%
#here i have used bs = blue squares and last code is 0 = hori graph
plt.boxplot(mba['gmat'],1,'bs',0)
plt.style.use(['tableau-colorblind10'])
